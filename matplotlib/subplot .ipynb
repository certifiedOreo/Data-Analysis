# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(2, 2, 1)
plt.subplot(2, 2, 2)
plt.subplot(2, 2, 3)
plt.subplot(2, 2, 4)
#plt.subplot(2, 2, 5)  this will give error, we can have atmost 4 subplots for 2 rows and 2 columns
# Out:
# <AxesSubplot:>

# %%
plt.subplot(2, 2, 1)
plt.pie([1])   #a pir chart on first subplot

plt.subplot(2, 2, 2)
plt.pie([1, 2,3])

plt.subplot(2, 2, 3)
plt.pie([1,2,3,4])

plt.subplot(2, 2, 4)
plt.pie([1,2])

plt.show()

# %%
plt.subplot(3, 2, 1)
plt.subplot(3, 2, 2)
plt.subplot(3, 2, 3)
plt.subplot(3, 2, 4)
plt.subplot(3, 2, 5)
plt.subplot(3, 2, 6)

plt.show()

# %%
#above sub plots are congested, lets change the figure size
plt.figure(figsize=(16, 9))
plt.subplot(3, 2, 1)
plt.subplot(3, 2, 2)
plt.subplot(3, 2, 3)
plt.subplot(3, 2, 4)
plt.subplot(3, 2, 5)
plt.subplot(3, 2, 6)

plt.show()

# %%
import numpy as np

# %%
days = np.arange(1, 31)
temperature = np.random.uniform(35.1, 49.9, 30)

# %%
#let's plot different graphs in these subplots
from matplotlib import style
plt.figure(figsize=(16, 9))
plt.subplot(3, 2, 1)
days = np.arange(1, 31)
delhi_temperature = np.random.uniform(35.1, 49.9, 30)
mumbai_temperature = np.random.uniform(35.1, 49.9, 30)
style.use("ggplot")
plt.plot(days, delhi_temperature, "go--", linewidth=2,
        markersize = 10, label="delhi temp")

plt.plot(days, mumbai_temperature, "mo:", linewidth=2,
        markersize = 10, label="mumbai temp")

plt.grid(color="k", linestyle="-", linewidth=2)
plt.axis([0, 30, 0, 55])
plt.title("Delhi & Mumbai Temperature", fontsize =15)
plt.xlabel("Days", fontsize =13)
plt.ylabel("temperature", fontsize =13)
plt.legend(loc=4)


#histogram at 2nd subplot
plt.subplot(3, 2, 2)
bins = [15, 20, 23, 30, 35, 40, 45]   #bar's category

plt.hist([ml_students_age,py_students_age], bins, rwidth=0.8, histtype="bar", color=["m", 'y'], label=["ML students", "Py students"]  )

#plt.hist(py_students_age, bins, rwidth=0.8, histtype="bar", color="g", label="ML students"  )

plt.title("ML students age histogram")
plt.xlabel("students age category")
plt.ylabel("No. of students age")
plt.legend()
plt.show()



#bar chart on 3rd subplot
classes = ["Python", "R", "AI", "ML", "DS"]
class1_students = [30, 10, 20, 25, 10]   #out of 100 students in each class
class2_students = [40, 2, 20, 20, 10]
class3_students = [35, 5, 30, 15, 15]
plt.subplot(3, 2, 3)
style.use("ggplot")
classes_index = np.arange(len(classes))
width = 0.2
plt.barh(classes_index, class1_students, width, align = "edge", color='b'
       , linewidth = 4, alpha = 0.9, label = "class 1 students", visible = True)


plt.barh(classes_index+width, class2_students, width, align = "edge", color='y'
       , linewidth = 4, alpha = 0.9, label = "class 2 students", visible = True)


plt.barh(classes_index+width+width, class3_students, width, align = "edge", color='g'
       , linewidth = 4, alpha = 0.9, label = "class 3 students", visible = True)

plt.xticks(classes_index+width, classes, rotation=20)
plt.title("Bar Chart of IAIP class", fontsize=18)
plt.xlabel("Classes", fontsize=15)
plt.ylabel("No. of students", fontsize=15)
plt.legend()
plt.show()
plt.subplot(3, 2, 4)
plt.subplot(3, 2, 5)
plt.subplot(3, 2, 6)

plt.show()
