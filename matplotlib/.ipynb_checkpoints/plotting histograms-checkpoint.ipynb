# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ml_students_age = np.random.randint(18, 45, 100)
py_students_age = np.random.randint(18, 40, 100)
ml_students_age
# Out:
# array([33, 31, 30, 19, 31, 30, 18, 25, 38, 29, 34, 23, 24, 25, 23, 29, 19,
#        36, 38, 18, 30, 38, 26, 39, 29, 25, 36, 25, 37, 34, 22, 22, 22, 32,
#        25, 21, 39, 35, 29, 24, 21, 37, 22, 27, 25, 34, 33, 20, 20, 30, 37,
#        28, 31, 28, 31, 25, 26, 33, 37, 21, 19, 32, 34, 29, 36, 27, 38, 22,
#        33, 39, 37, 19, 34, 36, 18, 22, 39, 39, 22, 29, 18, 28, 27, 32, 18,
#        37, 19, 22, 36, 39, 35, 30, 26, 19, 30, 31, 39, 27, 23, 24])

# %%
py_students_age
# Out:
# array([33, 31, 30, 19, 31, 30, 18, 25, 38, 29, 34, 23, 24, 25, 23, 29, 19,
#        36, 38, 18, 30, 38, 26, 39, 29, 25, 36, 25, 37, 34, 22, 22, 22, 32,
#        25, 21, 39, 35, 29, 24, 21, 37, 22, 27, 25, 34, 33, 20, 20, 30, 37,
#        28, 31, 28, 31, 25, 26, 33, 37, 21, 19, 32, 34, 29, 36, 27, 38, 22,
#        33, 39, 37, 19, 34, 36, 18, 22, 39, 39, 22, 29, 18, 28, 27, 32, 18,
#        37, 19, 22, 36, 39, 35, 30, 26, 19, 30, 31, 39, 27, 23, 24])

# %%
plt.hist(ml_students_age, )
plt.title("ML students age histogram")
plt.xlabel("students age category")
plt.ylabel("No. of students age")
# Out:
# Text(0, 0.5, 'No. of students age')

# %%
"""
plt.hist(
    x,
    bins=None,
    range=None,
    density=False,
    weights=None,
    cumulative=False,
    bottom=None,
    histtype='bar',
    align='mid',
    orientation='vertical',
    rwidth=None,
    log=False,
    color=None,
    label=None,
    stacked=False,
    *,
    data=None,
    **kwargs,
)

""" 

bins = [15, 20, 23, 30, 35, 40, 45]   #bar's category

plt.figure(figsize = (16, 9))
plt.hist([ml_students_age,py_students_age], bins, rwidth=0.8, histtype="bar", color=["m", 'y'], label=["ML students", "Py students"]  )

#plt.hist(py_students_age, bins, rwidth=0.8, histtype="bar", color="g", label="ML students"  )

plt.title("ML students age histogram")
plt.xlabel("students age category")
plt.ylabel("No. of students age")
plt.legend()

# %%
#change background of histogram
from matplotlib import style
style.use("ggplot")

plt.figure(figsize = (16, 9))
plt.hist([ml_students_age,py_students_age], bins, rwidth=0.8, histtype="bar", color=["m", 'y'], label=["ML students", "Py students"]  )

#plt.hist(py_students_age, bins, rwidth=0.8, histtype="bar", color="g", label="ML students"  )

plt.title("ML students age histogram")
plt.xlabel("students age category")
plt.ylabel("No. of students age")
plt.legend()
