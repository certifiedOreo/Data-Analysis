# %% [markdown]
# # How to plot Seaborn Histogram?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips_df["tip"])
plt.show()

# %%
"""
        sns.histplot(
    data=None,
    *,
    x=None,
    y=None,
    hue=None,
    weights=None,
    stat='count',
    bins='auto',
    binwidth=None,
    binrange=None,
    discrete=None,
    cumulative=False,
    common_bins=True,
    common_norm=True,
    multiple='layer',
    element='bars',
    fill=True,
    shrink=1,
    kde=False,
    kde_kws=None,
    line_kws=None,
    thresh=0,
    pthresh=None,
    pmax=None,
    cbar=False,
    cbar_ax=None,
    cbar_kws=None,
    palette=None,
    hue_order=None,
    hue_norm=None,
    color=None,
    log_scale=None,
    legend=True,
    ax=None,
    **kwargs,
)


"""
# Out:
# "\n        sns.histplot(\n    data=None,\n    *,\n    x=None,\n    y=None,\n    hue=None,\n    weights=None,\n    stat='count',\n    bins='auto',\n    binwidth=None,\n    binrange=None,\n    discrete=None,\n    cumulative=False,\n    common_bins=True,\n    common_norm=True,\n    multiple='layer',\n    element='bars',\n    fill=True,\n    shrink=1,\n    kde=False,\n    kde_kws=None,\n    line_kws=None,\n    thresh=0,\n    pthresh=None,\n    pmax=None,\n    cbar=False,\n    cbar_ax=None,\n    cbar_kws=None,\n    palette=None,\n    hue_order=None,\n    hue_norm=None,\n    color=None,\n    log_scale=None,\n    legend=True,\n    ax=None,\n    **kwargs,\n)\n\n\n"

# %%
sns.histplot(tips_df["total_bill"], bins=50, kde=True)
plt.show()

# %%
sns.histplot(tips_df["total_bill"], kde=True, color="r")
plt.show()

# %%
sns.histplot( tips_df["total_bill"], kde=True, color="r")
plt.show()

# %%
plt.figure(figsize=(16, 9))
sns.histplot( tips_df["total_bill"], kde=True, color="r",stat="count")
plt.title("Bill histogram", fontsize=20)
sns.set(style="darkgrid")
plt.show()

# %%
tips_df.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
#GRAPH UNDER DESIRED RANGE OF VALUES DEPENDENT VARIABLE
bins = [1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55]

plt.figure(figsize=(16, 9))
sns.histplot( tips_df["total_bill"], kde=True, color="r",stat="count", bins = bins)
plt.xticks(bins)
plt.title("Bill histogram", fontsize=20)
sns.set(style="darkgrid")
plt.show()

# %%
#hist keywords
plt.figure(figsize=(16, 9))
sns.histplot( tips_df["total_bill"], cbar = {
    'color' :'#DC143C',
    'edgecolor': '#aaff00',
    'linewidth':5
    
})
plt.title("Bill histogram", fontsize=20)
sns.set(style="darkgrid")
plt.show()
